# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kashi\Downloads\Uber Request Data.csv")
df
# Out:
#       Request id Pickup point  Driver id             Status Request timestamp  \
# 0            619      Airport        1.0     Trip Completed  11-07-2016 11:51
# 1            867      Airport        1.0     Trip Completed  11-07-2016 17:57
# 2           1807         City        1.0     Trip Completed  12-07-2016 09:17
# 3           2532      Airport        1.0     Trip Completed  12-07-2016 21:08
# 4           3112         City        1.0     Trip Completed  13-07-2016 08:33
# ...          ...          ...        ...                ...               ...
# 6740        6745         City        NaN  No Cars Available  15-07-2016 23:49
# 6741        6752      Airport        NaN  No Cars Available  15-07-2016 23:50
# 6742        6751         City        NaN  No Cars Available  15-07-2016 23:52
# 6743        6754         City        NaN  No Cars Available  15-07-2016 23:54
# 6744        6753      Airport        NaN  No Cars Available  15-07-2016 23:55
#
#         Drop timestamp
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df['request_timestamp'] = pd.to_datetime(df['request_timestamp'], errors='coerce', dayfirst=True)
df['drop_timestamp'] = pd.to_datetime(df['drop_timestamp'], errors='coerce', dayfirst=True)
df
# Out:
#       request_id pickup_point  driver_id             status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        request_timestamp      drop_timestamp
# 0    2016-07-11 11:51:00 2016-07-11 13:00:00
# 1    2016-07-11 17:57:00 2016-07-11 18:47:00
# 2    2016-07-12 09:17:00 2016-07-12 09:58:00
# 3    2016-07-12 21:08:00 2016-07-12 22:03:00
# ...

# %%
# DateTime (for sorting/grouping)
df['request_datetime'] = df['request_timestamp']
df['drop_datetime'] = df['drop_timestamp']
df['request_date'] = df['request_timestamp'].dt.date
df['drop_date'] = df['drop_timestamp'].dt.date
df
# Out:
#       request_id pickup_point  driver_id             status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        request_timestamp      drop_timestamp    request_datetime  \
# 0    2016-07-11 11:51:00 2016-07-11 13:00:00 2016-07-11 11:51:00
# 1    2016-07-11 17:57:00 2016-07-11 18:47:00 2016-07-11 17:57:00
# ...

# %%
# 12-hour format
df['request_time'] = df['request_timestamp'].dt.strftime('%I:%M:%S %p')
df['drop_time'] = df['drop_timestamp'].dt.strftime('%I:%M:%S %p')
df
# Out:
#       request_id pickup_point  driver_id             status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        request_timestamp      drop_timestamp request_time    drop_time
# 0    2016-07-11 11:51:00 2016-07-11 13:00:00  11:51:00 AM  01:00:00 PM
# 1    2016-07-11 17:57:00 2016-07-11 18:47:00  05:57:00 PM  06:47:00 PM
# ...

# %%
# for completed trips
df['trip_duration_min'] = (df['drop_timestamp'] - df['request_timestamp']).dt.total_seconds() / 60
df
# Out:
#       request_id pickup_point  driver_id             status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        request_timestamp      drop_timestamp request_time    drop_time  \
# 0    2016-07-11 11:51:00 2016-07-11 13:00:00  11:51:00 AM  01:00:00 PM
# 1    2016-07-11 17:57:00 2016-07-11 18:47:00  05:57:00 PM  06:47:00 PM
# ...

# %%
df = df.drop(columns=['request_timestamp', 'drop_timestamp'], errors='ignore')
df
# Out:
#       request_id pickup_point  driver_id             status request_time  \
# 0            619      Airport        1.0     Trip Completed  11:51:00 AM
# 1            867      Airport        1.0     Trip Completed  05:57:00 PM
# 2           1807         City        1.0     Trip Completed  09:17:00 AM
# 3           2532      Airport        1.0     Trip Completed  09:08:00 PM
# 4           3112         City        1.0     Trip Completed  08:33:00 AM
# ...          ...          ...        ...                ...          ...
# 6740        6745         City        NaN  No Cars Available  11:49:00 PM
# 6741        6752      Airport        NaN  No Cars Available  11:50:00 PM
# 6742        6751         City        NaN  No Cars Available  11:52:00 PM
# 6743        6754         City        NaN  No Cars Available  11:54:00 PM
# 6744        6753      Airport        NaN  No Cars Available  11:55:00 PM
#
#         drop_time  trip_duration_min
# 0     01:00:00 PM               69.0
# ...

# %%
df.to_excel('Uber_Request_Cleaned.xlsx', index=False)
df
# Out:
#       request_id pickup_point  driver_id             status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         request_datetime       drop_datetime request_date   drop_date  \
# 0    2016-07-11 11:51:00 2016-07-11 13:00:00   2016-07-11  2016-07-11
# 1    2016-07-11 17:57:00 2016-07-11 18:47:00   2016-07-11  2016-07-11
# ...

# %%
df.to_csv('Uber_File_cleaned.csv',index = False)
df
# Out:
#       request_id pickup_point  driver_id             status request_time  \
# 0            619      Airport        1.0     Trip Completed  11:51:00 AM
# 1            867      Airport        1.0     Trip Completed  05:57:00 PM
# 2           1807         City        1.0     Trip Completed  09:17:00 AM
# 3           2532      Airport        1.0     Trip Completed  09:08:00 PM
# 4           3112         City        1.0     Trip Completed  08:33:00 AM
# ...          ...          ...        ...                ...          ...
# 6740        6745         City        NaN  No Cars Available  11:49:00 PM
# 6741        6752      Airport        NaN  No Cars Available  11:50:00 PM
# 6742        6751         City        NaN  No Cars Available  11:52:00 PM
# 6743        6754         City        NaN  No Cars Available  11:54:00 PM
# 6744        6753      Airport        NaN  No Cars Available  11:55:00 PM
#
#         drop_time  trip_duration_min
# 0     01:00:00 PM               69.0
# ...
